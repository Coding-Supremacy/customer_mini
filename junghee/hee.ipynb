# %%
import pandas as pd

# %%
df = pd.read_csv('고객데이테수정.csv')

# %%
df = pd.read_csv('클러스터링고객데이터.csv')

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# 시각화: 클러스터별 평균 거래 금액, 구매 빈도, 연령대 비교
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# %%
df.head(1)
# Out:
#    연번 이름 (Name) 생년월일 (Date of Birth) 성별 (Gender) 휴대폰번호 (Phone Number)  \
# 0   1       강주온           2002-03-04           남        010-6502-8753
#
#             이메일 (Email)         주소 (Address) 아이디 (User ID)  \
# 0  janisi@himedia.co.kr  인천광역시 남동구 구월동 88-10         14798
#
#   가입일 (Registration Date) 차량구분(vehicle types) 구매한 제품 (Purchased Product)  \
# 0              2023-04-01              준중형 세단             Avante (CN7 N)
#
#   제품 구매 날짜 (Purchase Date)  거래 금액 (Transaction Amount)  \
# 0               2024-04-04                    35170000
#
#   거래 방식 (Transaction Method)  제품 구매 빈도 (Purchase Frequency)  \
# 0                         카드                              1
#
#   제품 구매 경로 (Purchase Path)  연령대 제품 출시년월 (Launch Date)  Cluster
# 0                     오프라인   23               2020-05        8

# %%
plt.subplots(figsize=(7, 4))

# %%
plt.subplots(figsize=(7, 4))
sns.boxplot(x=df['Cluster'], y=df['연령대'], palette='pastel')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1584\621881262.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['Cluster'], y=df['연령대'], palette='pastel')
# c:\Users\USER\anaconda3\envs\hi\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 50672 (\N{HANGUL SYLLABLE YEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\anaconda3\envs\hi\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47161 (\N{HANGUL SYLLABLE RYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\anaconda3\envs\hi\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.subplots(figsize=(7, 4))
sns.boxplot(x=df['Cluster'], y=df['제품 구매 빈도 (Purchase Frequency)'], palette='pastel')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1584\3734894067.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['Cluster'], y=df['제품 구매 빈도 (Purchase Frequency)'], palette='pastel')
# c:\Users\USER\anaconda3\envs\hi\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\anaconda3\envs\hi\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54408 (\N{HANGUL SYLLABLE PUM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\anaconda3\envs\hi\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
plt.subplots(figsize=(7, 4))
sns.boxplot(x=df['Cluster'], y=df['구매한 제품 (Purchased Product)'], palette='pastel')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1584\1539236009.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['Cluster'], y=df['구매한 제품 (Purchased Product)'], palette='pastel')
# c:\Users\USER\anaconda3\envs\hi\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\anaconda3\envs\hi\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 47588 (\N{HANGUL SYLLABLE MAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\anaconda3\envs\hi\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
plt.subplots(figsize=(7, 4))
sns.boxplot(x=df['Cluster'], y=df['거래 방식 (Transaction Method)'], palette='pastel')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1584\2688209215.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['Cluster'], y=df['거래 방식 (Transaction Method)'], palette='pastel')
# c:\Users\USER\anaconda3\envs\hi\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 52852 (\N{HANGUL SYLLABLE KA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\anaconda3\envs\hi\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\USER\anaconda3\envs\hi\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 54788 (\N{HANGUL SYLLABLE HYEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
plt.subplots(figsize=(7, 4))
sns.boxplot(x=df['Cluster'], y=df[''], palette='pastel')
plt.show()

# %%
df =pd.read_csv('D:\junghee\GitHub\customer_mini\프로모션Email_UTF8.csv')

# %%
import random

# %%
promo_contents = df[df['Cluster ID'] == 1]['이메일 본문'].tolist()

# %%
random.choice(promo_contents)
# Out:
# '준중형 세단을 선호하는 고객님을 위해 특별한 혜택을 준비했습니다. 현대차 트레이드인 보상 프로모션! 기존 차량 반납 시 최대 100만원 보상 혜택을 제공합니다., 현대차 무료 용품 프로모션! 차량용 공기청정기 증정 혜택을 제공합니다., 현대차 보험 지원 프로모션! 운전자 보험 무료 제공 혜택을 제공합니다.. 지금 확인하세요.'

# %%
df = pd.read_csv('D:\junghee\GitHub\customer_mini\클러스터링별_이메일_UTF8.csv')

# %%
promo_contents = df[df['클러스터 ID'] == 1][['이메일 본문', '제목']]

# %%
promo_contents[['이메일 본문', '제목']]
# Out:
#                                         이메일 본문                              제목
# 50           고객님의 라이프스타일에 맞춘 맞춤형 구매 혜택을 확인하세요.  VIP 고객님, 프리미엄 무이자 할부 혜택을 확인하세요
# 51     VIP 고객 대상, 한정 수량 특별 구매 혜택 제공! 지금 확인하세요.  VIP 고객님, 프리미엄 무이자 할부 혜택을 확인하세요
# 52  VIP 고객 한정, 3년 무이자 할부 및 추가 서비스 제공 이벤트 진행 중.       VIP 전용 보증 연장 및 특별 프로모션 안내
# 53            이번 달 한정, 보증 연장 및 정기점검 서비스 무료 제공.  VIP 고객님, 프리미엄 무이자 할부 혜택을 확인하세요
# 54  VIP 고객 한정, 3년 무이자 할부 및 추가 서비스 제공 이벤트 진행 중.           프리미엄 차량 구매 시 한정 혜택 제공
# 55            이번 달 한정, 보증 연장 및 정기점검 서비스 무료 제공.           프리미엄 차량 구매 시 한정 혜택 제공
# 56            이번 달 한정, 보증 연장 및 정기점검 서비스 무료 제공.  VIP 고객님, 프리미엄 무이자 할부 혜택을 확인하세요
# 57            이번 달 한정, 보증 연장 및 정기점검 서비스 무료 제공.       VIP 전용 보증 연장 및 특별 프로모션 안내
# 58            이번 달 한정, 보증 연장 및 정기점검 서비스 무료 제공.       VIP 전용 보증 연장 및 특별 프로모션 안내
# 59         프리미엄 차량을 부담 없이! 무이자 할부 혜택을 놓치지 마세요.  VIP 고객님, 프리미엄 무이자 할부 혜택을 확인하세요
# 60           고객님의 라이프스타일에 맞춘 맞춤형 구매 혜택을 확인하세요.           프리미엄 차량 구매 시 한정 혜택 제공
# ...

# %%
random.choice(promo_contents[['이메일 본문', '제목']].values.tolist())[0],random.choice(promo_contents[['이메일 본문', '제목']].values.tolist())[1]

# %%
promo_contents.sample(n=1).iloc[0]
# Out:
# 이메일 본문    VIP 고객 대상, 한정 수량 특별 구매 혜택 제공! 지금 확인하세요.
# 제목                          프리미엄 차량 구매 시 한정 혜택 제공
# Name: 90, dtype: object
